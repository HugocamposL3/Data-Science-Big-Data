# %% [markdown]
# <a href="https://colab.research.google.com/github/HugocamposL3/Data-Science-Big-Data/blob/main/Regressao_Logistica_CardCredit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Doing Imports - Fazendo Imports das Bibliotecas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from matplotlib import pyplot as plt
from sklearn import metrics

import seaborn as sn

# %% [markdown]
# ## Loading the data using Pandas - Carregando os Dados Usando Pandas

# %%
df1 = pd.read_csv('/content/creditcard.csv')

# %%
df1.head(10)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
# 5   2.0 -0.425966  0.960523  1.141109  ...  0.253844  0.081080    3.67      0
# 6   4.0  1.229658  0.141004  0.045371  ...  0.034507  0.005168    4.99      0
# 7   7.0 -0.644269  1.417964  1.074380  ... -1.206921 -1.085339   40.80      0
# 8   7.0 -0.894286  0.286157 -0.113192  ...  0.011747  0.142404   93.20      0
# 9   9.0 -0.338262  1.119593  1.044367  ...  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
df1.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df1.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df1.isnull().sum() ## Para ver se temos números nulos no Dataframe

# %%
X = df1[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']]
y = df1['Class']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
logistic_regression= LogisticRegression()
logistic_regression.fit(X_train,y_train)
y_pred=logistic_regression.predict(X_test)

# %%
confusion_matrix = pd.crosstab(y_test,y_pred,rownames=['Real'],colnames=['Predição'])
sn.heatmap(confusion_matrix,annot=True)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
plt.show()
# Out:
# Accuracy:  0.9991011488441336

# %%
print (X_test)
print (y_pred)
# Out:
#             Time        V1        V2  ...       V27       V28  Amount
# 183484  125821.0 -0.323334  1.057455  ...  0.108494  0.161139   40.00
# 255448  157235.0 -0.349718  0.932619  ...  0.076830  0.175562    1.98
# 244749  152471.0 -1.614711 -2.406570  ...  0.286285  0.437322   96.00
# 63919    50927.0 -2.477184  0.860613  ... -0.510060 -0.660533  308.00
# 11475    19899.0  1.338831 -0.547264  ... -0.002769  0.003272    5.00
# ...          ...       ...       ...  ...       ...       ...     ...
# 52247    45350.0 -0.636269  0.067181  ...  0.384712  0.199361   19.53
# 247905  153730.0 -0.341844 -0.460832  ...  0.251512 -0.015190    3.00
# 78338    57481.0  1.403221 -0.439300  ... -0.010405  0.006489   10.00
# 246056  153018.0 -3.231311  2.103140  ...  0.472313 -0.192529   99.99
# 40618    40319.0  1.257561 -0.724477  ... -0.101754  0.011956   90.00
#
# [71202 rows x 30 columns]
# None

# %%
y_pred=df1.to_csv('y_previsto')
